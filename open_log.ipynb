# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import glob

filename_list = glob.glob('./logdir/20250304T023151/replay/*.npz')
print(filename_list)
# memmap을 사용하여 파일을 읽습니다.
# mode='r'은 읽기 전용 모드입니다.
data = np.load(filename_list[0])

# data.shape는 기본적으로 1차원 배열로 나오므로, replay buffer의 구조(예: 샘플 수, 각 샘플의 차원)를 알아야 reshape할 수 있습니다.
print("Raw data shape:", data)
# Out:
# ['./logdir/20250304T023151/replay/20250304T023913F054402-0frfnVnpqfYJRYcMk69IOL-5pZTZqLlALIxEwr4JjgHIN-1024.npz', './logdir/20250304T023151/replay/20250304T024600F460220-0cIMqPvLLvFSEcIrsKqNIx-1rptQZFa6gjGbehq6SGTqK-281.npz', './logdir/20250304T023151/replay/20250304T024600F460378-4Pz5BP0meycijifdUtieUB-75N2nrB35ubzlTzol8mjLw-281.npz', './logdir/20250304T023151/replay/20250304T023913F051804-2rV2u8x2tj1Z24mqwjWT80-3sM2RFDmil7bUAs3u8hM1T-1024.npz', './logdir/20250304T023151/replay/20250304T023251F918077-0UFmlkNqjYOdk3wMl2ca11-6ZlHUsx5ULJmJA3WYjozLR-1024.npz', './logdir/20250304T023151/replay/20250304T024600F461964-4DfnCeciBkFk59lhHMtIGc-5QawRV0Vk2RS3rWY2nNz5L-281.npz', './logdir/20250304T023151/replay/20250304T023251F920308-4sFrE9GdCtsdy0HDuwnXx2-0tC8j5iGnHO1aZuBVBUnnZ-1024.npz', './logdir/20250304T023151/replay/20250304T024600F461242-6Quti7FXxcMOfDbkBle3l1-4f4mascw5yBgmAp0W9SINx-281.npz', './logdir/20250304T023151/replay/20250304T023251F923299-2tkYpGOurQ7zDxv9ivDHU0-2hLF7W9FaVsqOs9tXe
# ...

# %%
plt.imshow(data['image'][0])
plt.show()

# %%
data.files
# Out:
# ['image',
#  'reward',
#  'is_first',
#  'is_last',
#  'is_terminal',
#  'action',
#  'dyn/deter',
#  'dyn/stoch',
#  'stepid']
